# %%
import pandas as pd

bolly=pd.read_csv("bollywood.csv")
print("Vicky Kaushal :",bolly[bolly["lead"]=="Vicky Kaushal"].shape[0]) # OR USE len()

print(bolly[bolly["movie"]=="Kaante"]["lead"])
# Out:
# Vicky Kaushal : 2
# 1494    Amitabh Bachchan
# Name: lead, dtype: object

# %%
import pandas as pd

movies=pd.read_csv("movies.csv")
print(movies[(movies["year_of_release"]==2019) & (movies["imdb_rating"]>=7)].shape[0])
data=(movies[movies["imdb_votes"]>=20000])
data[["original_title","story","wiki_link"]]
# movies
# Out:
# 27
#                          original_title  \
# 0              Uri: The Surgical Strike
# 11                            Gully Boy
# 36                          Kabir Singh
# 74                          Dil Bechara
# 88                            Padmaavat
# ...                                 ...
# 1490                             Devdas
# 1565        Kabhi Khushi Kabhie Gham...
# 1567  Lagaan: Once Upon a Time in India
# 1568  Lagaan: Once Upon a Time in India
# 1571                     Dil Chahta Hai
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 11    Gully Boy is a film about a 22-year-old boy "M...
# 36    This Sandeep Vanga directorial is a remake of ...
# 74              A love story about two cancer patients.
# 88    This fictional story is set in 13th century me...
# ...                                                 ...
# 1490  Devdas Mukherji is black-listed by his multi-m...
# ...

# %%
data=(movies[movies["imdb_votes"]>=20000])

mydata=data[["original_title","story","wiki_link"]]

# %%
mydata
# Out:
#                          original_title  \
# 0              Uri: The Surgical Strike
# 11                            Gully Boy
# 36                          Kabir Singh
# 74                          Dil Bechara
# 88                            Padmaavat
# ...                                 ...
# 1490                             Devdas
# 1565        Kabhi Khushi Kabhie Gham...
# 1567  Lagaan: Once Upon a Time in India
# 1568  Lagaan: Once Upon a Time in India
# 1571                     Dil Chahta Hai
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 11    Gully Boy is a film about a 22-year-old boy "M...
# 36    This Sandeep Vanga directorial is a remake of ...
# 74              A love story about two cancer patients.
# 88    This fictional story is set in 13th century me...
# ...                                                 ...
# 1490  Devdas Mukherji is black-listed by his multi-m...
# ...

# %%
mydata.to_csv("new.csv",index=False)

# %%
import pandas as pd

movies=pd.read_csv("movies.csv")
m2019=movies[(movies["year_of_release"]==2019)].reset_index(drop=True)
name=m2019["title_x"]
date=m2019["release_date"]
for i in name:
    print(m2019["title_x"],":",m2019["release_date"])
# Out:
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                            Fraud Saiyaan
#                       ...
# 70                       Commando 3 (film)
# 71                              Mardaani 2
# 72                               Dabangg 3
# 73                              Good Newwz
# 74                                   Daaka
# Name: title_x, Length: 75, dtype: object : 0       11 January 2019 (USA)
# 1     11 January 2019 (India)
# 2       11 January 2019 (USA)
# 3       18 January 2019 (USA)
# 4     18 January 2019 (India)
#                ...
# 70                        NaN
# 71                        NaN
# 72                        NaN
# 73                        NaN
# 74      1 November 2019 (USA)
# Name: release_date, Length: 75, dtype: object
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# ...
